# %%
import pandas as pd

df = pd.read_csv('data/stocks_to_display.csv')
df
# Out:
#       Unnamed: 0        Date  Adj Close IBM  Adj Close AAPL  Adj Close AMZN  \
# 0           8905  1997-05-15      27.815508        0.551582        1.958333
# 1           8906  1997-05-16      27.195616        0.536044        1.729167
# 2           8907  1997-05-19      26.995653        0.528276        1.708333
# 3           8908  1997-05-20      27.795517        0.536044        1.635417
# 4           8909  1997-05-21      28.015465        0.524391        1.427083
# ...          ...         ...            ...             ...             ...
# 5666       14571  2019-11-19     134.520004      266.290009     1752.790039
# 5667       14572  2019-11-20     133.199997      263.190002     1745.530029
# 5668       14573  2019-11-21     133.839996      262.010010     1734.709961
# 5669       14574  2019-11-22     134.339996      261.779999     1745.719971
# 5670       14575  2019-11-25     135.970001      266.369995     1773.839966
#
#       Return IBM  Return AAPL  Return AMZN
# ...

# %%
df = df.drop('Unnamed: 0', 1)
df
# Out:
#             Date  Adj Close IBM  Adj Close AAPL  Adj Close AMZN  Return IBM  \
# 0     1997-05-15      27.815508        0.551582        1.958333         NaN
# 1     1997-05-16      27.195616        0.536044        1.729167   -0.022286
# 2     1997-05-19      26.995653        0.528276        1.708333   -0.007353
# 3     1997-05-20      27.795517        0.536044        1.635417    0.029629
# 4     1997-05-21      28.015465        0.524391        1.427083    0.007913
# ...          ...            ...             ...             ...         ...
# 5666  2019-11-19     134.520004      266.290009     1752.790039    0.001564
# 5667  2019-11-20     133.199997      263.190002     1745.530029   -0.009813
# 5668  2019-11-21     133.839996      262.010010     1734.709961    0.004805
# 5669  2019-11-22     134.339996      261.779999     1745.719971    0.003736
# 5670  2019-11-25     135.970001      266.369995     1773.839966    0.012133
#
#       Return AAPL  Return AMZN
# ...

# %%
df = df.set_index('Date')
df
# Out:
#             Adj Close IBM  Adj Close AAPL  Adj Close AMZN  Return IBM  \
# Date
# 1997-05-15      27.815508        0.551582        1.958333         NaN
# 1997-05-16      27.195616        0.536044        1.729167   -0.022286
# 1997-05-19      26.995653        0.528276        1.708333   -0.007353
# 1997-05-20      27.795517        0.536044        1.635417    0.029629
# 1997-05-21      28.015465        0.524391        1.427083    0.007913
# ...                   ...             ...             ...         ...
# 2019-11-19     134.520004      266.290009     1752.790039    0.001564
# 2019-11-20     133.199997      263.190002     1745.530029   -0.009813
# 2019-11-21     133.839996      262.010010     1734.709961    0.004805
# 2019-11-22     134.339996      261.779999     1745.719971    0.003736
# 2019-11-25     135.970001      266.369995     1773.839966    0.012133
#
#             Return AAPL  Return AMZN
# Date
# 1997-05-15          NaN          NaN
# 1997-05-16    -0.028170    -0.117021
# ...

# %%
df.plot(kind='line', y=['Adj Close IBM', 'Adj Close AAPL', 'Adj Close AMZN'])

# %%
df[0:100].plot(kind='line', y=['Adj Close IBM', 'Adj Close AAPL', 'Adj Close AMZN'])

# %%
df_display = df[['Adj Close IBM', 'Adj Close AAPL', 'Adj Close AMZN']]
df_display
# Out:
#             Adj Close IBM  Adj Close AAPL  Adj Close AMZN
# Date
# 1997-05-15      27.815508        0.551582        1.958333
# 1997-05-16      27.195616        0.536044        1.729167
# 1997-05-19      26.995653        0.528276        1.708333
# 1997-05-20      27.795517        0.536044        1.635417
# 1997-05-21      28.015465        0.524391        1.427083
# ...                   ...             ...             ...
# 2019-11-19     134.520004      266.290009     1752.790039
# 2019-11-20     133.199997      263.190002     1745.530029
# 2019-11-21     133.839996      262.010010     1734.709961
# 2019-11-22     134.339996      261.779999     1745.719971
# 2019-11-25     135.970001      266.369995     1773.839966
#
# [5671 rows x 3 columns]

# %%
# lambda x: x / x[0]
def my_func(x):
    return x / x[0]

df_display = df_display.apply(my_func)
df_display
# Out:
#             Adj Close IBM  Adj Close AAPL  Adj Close AMZN
# Date
# 1997-05-15       1.000000        1.000000        1.000000
# 1997-05-16       0.977714        0.971830        0.882979
# 1997-05-19       0.970525        0.957747        0.872340
# 1997-05-20       0.999281        0.971830        0.835107
# 1997-05-21       1.007189        0.950704        0.728723
# ...                   ...             ...             ...
# 2019-11-19       4.836151      482.775016      895.041874
# 2019-11-20       4.788695      477.154806      891.334635
# 2019-11-21       4.811704      475.015519      885.809493
# 2019-11-22       4.829680      474.598517      891.431626
# 2019-11-25       4.888280      482.920028      905.790775
#
# [5671 rows x 3 columns]

# %%
df_display.plot(kind='line')

# %%
df_display[0:1000].plot(kind='line')

# %%
df_display.plot(kind='line', subplots=True)
# Out:
# array([<matplotlib.axes._subplots.AxesSubplot object at 0x118ced110>,
# ...
#       dtype=object)

# %%
df_display.plot(kind='line', logy=True)

# %%
df_display.plot(kind='line', title='Stock Prices')

# %%
df_display.plot(kind='line', title='Stock Prices', logy=True, grid=True)

# %%
df_display.plot(kind='line', title='Stock Prices', logy=True, grid=True, figsize=(15, 15))

# %%
df_aapl_returns = df[['Return AAPL']]
df_aapl_returns
# Out:
#             Return AAPL
# Date
# 1997-05-15          NaN
# 1997-05-16    -0.028170
# 1997-05-19    -0.014491
# 1997-05-20     0.014704
# 1997-05-21    -0.021739
# ...                 ...
# 2019-11-19    -0.003033
# 2019-11-20    -0.011641
# 2019-11-21    -0.004483
# 2019-11-22    -0.000878
# 2019-11-25     0.017534
#
# [5671 rows x 1 columns]

# %%
df_aapl_returns.plot(kind='hist')

# %%
df_aapl_returns.plot(kind='hist', bins=100)

# %%
df_aapl_returns.plot(kind='hist', bins=100, grid=True, figsize=(15, 15))

# %%
df_aapl = pd.read_csv('data/AAPL.csv')
df_aapl
# Out:
#             Date        Open        High         Low       Close   Adj Close  \
# 0     1980-12-12    0
# Date
# ...

# %%
df_aapl[['Adj Close', '200 Day Moving Average']].plot(kind='line', figsize=(17, 7), title='Apple (AAPL)')
df_aapl[['Volume']].plot(kind='area', color='red', figsize=(17, 3))

# %%
df_aapl['2004-09-21':'2004-09-28']
# Out:
#                 Open      High       Low     Close  Adj Close       Volume  \
# Date
# 2004-09-21  2.696429  2.776428  2.675714  2.715000   2.362324   96663000.0
# 2004-09-22  2.721429  2.724286  2.629286  2.637143   2.294580  100422000.0
# 2004-09-23  2.645714  2.678571  2.637857  2.662143   2.316333   99351000.0
# 2004-09-24  2.675000  2.714286  2.653571  2.663571   2.317576   92372000.0
# 2004-09-27  2.639286  2.712857  2.630714  2.680714   2.332493   99379000.0
# 2004-09-28  2.675714  2.735000  2.675000  2.717143   2.364189   88296600.0
#
#             5 Day Moving Average  200 Day Moving Average
# Date
# 2004-09-21              2.292219                1.715796
# 2004-09-22              2.313599                1.720696
# 2004-09-23              2.325034                1.725799
# 2004-09-24              2.326899                1.730845
# 2004-09-27              2.324661                1.736153
# 2004-09-28              2.325034                1.741641

# %%
df_aapl['2019-09-21':'2019-09-28']
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2019-09-23  218.949997  219.839996  217.649994  218.720001  218.065308
# 2019-09-24  221.029999  222.490005  217.190002  217.679993  217.028412
# 2019-09-25  218.550003  221.500000  217.139999  221.029999  220.368393
# 2019-09-26  220.000000  220.940002  218.830002  219.889999  219.231812
# 2019-09-27  220.539993  220.960007  217.279999  218.820007  218.165024
#
#                 Volume  5 Day Moving Average  200 Day Moving Average
# Date
# 2019-09-23  19165500.0            219.516953              186.695038
# 2019-09-24  31190800.0            218.914758              186.919512
# 2019-09-25  21903400.0            218.567798              187.191374
# 2019-09-26  18833500.0            218.354437              187.452086
# 2019-09-27  25352000.0            218.571790              187.712242

# %%
df_amzn = pd.read_csv('data/AMZN.csv')
df_amzn = df_amzn.set_index('Date')
df_amzn
# Out:
#                    Open         High          Low        Close    Adj Close  \
# Date
# 1997-05-15     2.437500     2.500000     1.927083     1.958333     1.958333
# 1997-05-16     1.968750     1.979167     1.708333     1.729167     1.729167
# 1997-05-19     1.760417     1.770833     1.625000     1.708333     1.708333
# 1997-05-20     1.729167     1.750000     1.635417     1.635417     1.635417
# 1997-05-21     1.635417     1.645833     1.375000     1.427083     1.427083
# ...                 ...          ...          ...          ...          ...
# 2019-11-19  1756.989990  1760.680054  1743.030029  1752.790039  1752.790039
# 2019-11-20  1749.140015  1762.520020  1734.119995  1745.530029  1745.530029
# 2019-11-21  1743.000000  1746.869995  1730.359985  1734.709961  1734.709961
# 2019-11-22  1739.020020  1746.430054  1731.000000  1745.719971  1745.719971
# 2019-11-25  1753.250000  1777.420044  1753.239990  1773.839966  1773.839966
#
#               Volume
# Date
# ...

# %%
df_amzn[['Adj Close']].plot(kind='line', figsize=(17, 7), title='Amazon (AMZN)')
df_amzn[['Volume']].plot(kind='area', color='red', figsize=(17, 3))
